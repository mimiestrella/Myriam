# %% [markdown]
# #gestion de datos

# %%
# %ls
# Out:
# 00_00_binder.ipynb                    census.csv
# 00_00_primer_pasos.ipynb              class2.ipynb
# 01_01_data_types.ipynb                coches.csv
# 01_02_read_iloc_unique_groupby.ipynb  cwurData.csv
# 02_00_data_wrangling.ipynb            data.csv
# 02_01_null_display.ipynb              headbrain.csv
# 02_02_basic_math.ipynb                movies.csv
# adult.csv                             nhanes_2015_2016.csv
# airline_data.csv                      pokemon.csv
# antropometria00.csv                   README.md
# antropometria-dataset.csv             requirements.txt
# Book3.csv                             sample_pivot.csv
# Cartwheeldata.csv                     Untitled.ipynb

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
path ='Cartwheeldata.csv'
df = pd.read_csv(path)
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
# %ls Cartwheeldata.csv
# Out:
# Cartwheeldata.csv

# %%
x= list(df.columns)
x.sort()
x
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(x)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# #selesccionar variables especificas

# %% [markdown]
# usamos iloc y loc

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df [['Age','Height']]
# Out:
#     Age  Height
# 0    56   62.00
# 1    26   62.00
# 2    33   66.00
# 3    39   64.00
# 4    27   73.00
# 5    24   75.00
# 6    28   75.00
# 7    22   65.00
# 8    29   74.00
# 9    33   63.00
# 10   30   69.50
# 11   28   62.75
# 12   25   65.00
# 13   23   61.50
# 14   31   73.00
# 15   26   71.00
# 16   26   61.50
# 17   27   66.00
# 18   23   70.00
# 19   24   68.00
# 20   23   69.00
# 21   29   71.00
# 22   25   70.00
# 23   26   69.00
# 24   23   65.00

# %%
df['Age'].head(2)
# Out:
# 0    56
# 1    26
# Name: Age, dtype: int64

# %%
df[['Age','Height','CWDistance']].head(2)
# Out:
#    Age  Height  CWDistance
# 0   56    62.0          79
# 1   26    62.0          70

# %%
df[['Age','Height','CWDistance']].head(4)
# Out:
#    Age  Height  CWDistance
# 0   56    62.0          79
# 1   26    62.0          70
# 2   33    66.0          85
# 3   39    64.0          87

# %%
y=df[['Age']].head(2)
y
# Out:
#    Age
# 0   56
# 1   26

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
ndf= df.loc[:'Glasses']
ndf
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
ndc=df.loc[:, :'Glasses']
ndf
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
ndf= df.iloc[3:5, :5]
ndf
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 3   4   39      F            1       N
# 4   5   27      M            2       N
