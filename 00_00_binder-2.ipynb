# %% [markdown]
# # Páginas para programar python

# %% [markdown]
# 1. www.mybinder.org
# 2. www.kaggle.com
# 3. www.jupyter.org/try
# 4. `github jobish` https://mybinder.org/v2/gh/jobish03/jobish03-Visualizacion_de_datos_para_la_toma_de_decisiones/main?filepath=welcome_binder.ipynb
#
# Los paquetes hay que incluir en el archivo `requirements.txt`

# %% [markdown]
# # class 2

# %%
import numpy as np

# %%
type (3)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
type(3/5)
# Out:
# float

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type('math.pi')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(True)
# Out:
# bool

# %% [markdown]
# #listas

# %%
una_lista = [1,3/5, 'nombre', math.pi, True, 5<=3, 1==3, 3==3, None]
una_lista
# Out:
# [1, 0.6, 'nombre', 3.141592653589793, True, False, False, True, None]

# %%
str_list= ['zeroth','first', 'second', 'third', 'fourth', 'fifth', 'sixth']
str_list
# Out:
# ['zeroth', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
str_list.sort()
str_list
# Out:
# ['fifth', 'first', 'fourth', 'second', 'sixth', 'third', 'zeroth']

# %%
numbers= [11,20,3,14,53,61]
numbers
# Out:
# [11, 20, 3, 14, 53, 61]

# %%
numbers[2]
# Out:
# 3

# %%
numbers[0]
# Out:
# 11

# %%
numbers[-1]
# Out:
# 61

# %%
numbers[0:3]
# Out:
# [11, 20, 3]

# %%
numbers[2:5]
# Out:
# [3, 14, 53]

# %%
numbers[-3:-1]
# Out:
# [14, 53]

# %%
numbers[-3:]
# Out:
# [14, 53, 61]

# %%
x= sum(numbers)
x
# Out:
# 162

# %%
y= len(numbers)
y
# Out:
# 6

# %%
promedio=x/y
promedio
# Out:
# 27.0

# %% [markdown]
# #una for loop

# %%
numbers
# Out:
# [11, 20, 3, 14, 53, 61]

# %%
for i in una_lista:
    print(i,'\t\t',type(1))
# Out:
# 1 		 <class 'int'>
# 0.6 		 <class 'int'>
# nombre 		 <class 'int'>
# 3.141592653589793 		 <class 'int'>
# True 		 <class 'int'>
# False 		 <class 'int'>
# False 		 <class 'int'>
# True 		 <class 'int'>
# None 		 <class 'int'>

# %%
x = 6
y = 1
if x < y:
    print(' x es menor que y ' )
else:
    print( ' x es mayor que y ' )
# Out:
#  x es mayor que y

# %%
x = 6
y = 1
if x < y:
    print(' {} x es menor que y {} ' .format(x,y))
else:
    print( ' {} x es mayor que y {} ' .format(x,y))
# Out:
#  6 x es mayor que y 1

# %%
# Out:
#   File "/tmp/ipykernel_79/1969652708.py", line 1
#     mamba install -c conda-forge jupyterlab
#           ^
# SyntaxError: invalid syntax
